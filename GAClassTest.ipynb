# %%
import pygad
import numpy as np
import pandas as pd
from MP3NoiseEvalClass import MP3NoiseEvalClass
from GAParameterClass import GAParameterClass
import argparse
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings("ignore", "Possible clipped samples in output.")

# %% [markdown]
# # Solution Number

# %%
GA_sol_per_pop_12 = GAParameterClass(num_generations=100,mutation_percent_genes=25,num_parents_mating=2,sol_per_pop=12,crossover_type="single_point")
GA_sol_per_pop_12.run()
score_df_sol_per_pop_12, manip_df_sol_per_pop_12, full_df_sol_per_pop_12 = GA_sol_per_pop_12.OutputDateFrame()
# Out:
# Vocal duration orginal is 75.73730158730159 seconds, now is the 8.0, the audio changing to the MONO
# Drum duration orginal is 75.73730158730159 seconds, now is the 8.0, the audio changing to the MONO
# Bass duration orginal is 75.73730158730159 seconds, now is the 8.0, the audio changing to the MONO
# Other duration orginal is 75.73730158730159 seconds, now is the 8.0,  the audio changing to the MONO
# Mixing File Load Sucessful
# /root/anaconda3/lib/python3.11/site-packages/pygad/pygad.py:1139: UserWarning: The 'delay_after_gen' parameter is deprecated starting from PyGAD 3.3.0. To delay or pause the evolution after each generation, assign a callback function/method to the 'on_generation' parameter to adds some time delay.
#   warnings.warn("The 'delay_after_gen' parameter is deprecated starting from PyGAD 3.3.0. To delay or pause the evolution after each generation, assign a callback function/method to the 'on_generation' parameter to adds some time delay.")
# ...

# %%
score_df_sol_per_pop_12, manip_df_sol_per_pop_12, full_df_sol_per_pop_12 = GA_sol_per_pop_12.OutputDateFrame()

# %%
GA_sol_per_pop_6 = GAParameterClass(num_generations=100,mutation_percent_genes=25,num_parents_mating=2,sol_per_pop=6,crossover_type="single_point")
GA_sol_per_pop_6.run()
score_df_sol_per_pop_6, manip_df_sol_per_pop_6, full_df_sol_per_pop_6 = GA_sol_per_pop_6.OutputDateFrame()
# Out:
# Vocal duration orginal is 75.73730158730159 seconds, now is the 8.0, the audio changing to the MONO
# Drum duration orginal is 75.73730158730159 seconds, now is the 8.0, the audio changing to the MONO
# Bass duration orginal is 75.73730158730159 seconds, now is the 8.0, the audio changing to the MONO
# Other duration orginal is 75.73730158730159 seconds, now is the 8.0,  the audio changing to the MONO
# Mixing File Load Sucessful
# /root/anaconda3/lib/python3.11/site-packages/pygad/pygad.py:1139: UserWarning: The 'delay_after_gen' parameter is deprecated starting from PyGAD 3.3.0. To delay or pause the evolution after each generation, assign a callback function/method to the 'on_generation' parameter to adds some time delay.
#   warnings.warn("The 'delay_after_gen' parameter is deprecated starting from PyGAD 3.3.0. To delay or pause the evolution after each generation, assign a callback function/method to the 'on_generation' parameter to adds some time delay.")
# ...

# %%
GA_sol_per_pop_3 = GAParameterClass(num_generations=100,mutation_percent_genes=25,num_parents_mating=2,sol_per_pop=3,crossover_type="single_point")
GA_sol_per_pop_3.run()
score_df_sol_per_pop_3, manip_df_sol_per_pop_3, full_df_sol_per_pop_3 = GA_sol_per_pop_3.OutputDateFrame()
# Out:
# Vocal duration orginal is 75.73730158730159 seconds, now is the 8.0, the audio changing to the MONO
# Drum duration orginal is 75.73730158730159 seconds, now is the 8.0, the audio changing to the MONO
# Bass duration orginal is 75.73730158730159 seconds, now is the 8.0, the audio changing to the MONO
# Other duration orginal is 75.73730158730159 seconds, now is the 8.0,  the audio changing to the MONO
# Mixing File Load Sucessful
# /root/anaconda3/lib/python3.11/site-packages/pygad/pygad.py:1139: UserWarning: The 'delay_after_gen' parameter is deprecated starting from PyGAD 3.3.0. To delay or pause the evolution after each generation, assign a callback function/method to the 'on_generation' parameter to adds some time delay.
#   warnings.warn("The 'delay_after_gen' parameter is deprecated starting from PyGAD 3.3.0. To delay or pause the evolution after each generation, assign a callback function/method to the 'on_generation' parameter to adds some time delay.")
# ...

# %%
GA_sol_per_pop_24 = GAParameterClass(num_generations=100,mutation_percent_genes=25,num_parents_mating=2,sol_per_pop=24,crossover_type="single_point")
GA_sol_per_pop_24.run()
score_df_sol_per_pop_24, manip_df_sol_per_pop_24, full_df_sol_per_pop_24 = GA_sol_per_pop_24.OutputDateFrame()
GA_sol_per_pop_48 = GAParameterClass(num_generations=100,mutation_percent_genes=25,num_parents_mating=2,sol_per_pop=48,crossover_type="single_point")
GA_sol_per_pop_48.run()
score_df_sol_per_pop_48, manip_df_sol_per_pop_48, full_df_sol_per_pop_48 = GA_sol_per_pop_48.OutputDateFrame()
# Out:
# Vocal duration orginal is 75.73730158730159 seconds, now is the 8.0, the audio changing to the MONO
# Drum duration orginal is 75.73730158730159 seconds, now is the 8.0, the audio changing to the MONO
# Bass duration orginal is 75.73730158730159 seconds, now is the 8.0, the audio changing to the MONO
# Other duration orginal is 75.73730158730159 seconds, now is the 8.0,  the audio changing to the MONO
# Mixing File Load Sucessful
# /root/anaconda3/lib/python3.11/site-packages/pygad/pygad.py:1139: UserWarning: The 'delay_after_gen' parameter is deprecated starting from PyGAD 3.3.0. To delay or pause the evolution after each generation, assign a callback function/method to the 'on_generation' parameter to adds some time delay.
#   warnings.warn("The 'delay_after_gen' parameter is deprecated starting from PyGAD 3.3.0. To delay or pause the evolution after each generation, assign a callback function/method to the 'on_generation' parameter to adds some time delay.")
# ...

# %% [markdown]
# ## Ploting the solution

# %%
##Interigrity the data
if score_df_sol_per_pop_48["score"][0]>0:
    score_df_sol_per_pop_48["score"] = -score_df_sol_per_pop_48["score"]
if score_df_sol_per_pop_24["score"][0]>0:
    score_df_sol_per_pop_24["score"] = -score_df_sol_per_pop_24["score"]
if score_df_sol_per_pop_12["score"][0]>0:
    score_df_sol_per_pop_12["score"] = -score_df_sol_per_pop_12["score"]
if score_df_sol_per_pop_6["score"][0]>0:
    score_df_sol_per_pop_6["score"] = -score_df_sol_per_pop_6["score"]
if score_df_sol_per_pop_3["score"][0]>0:
    score_df_sol_per_pop_3["score"] = -score_df_sol_per_pop_3["score"]

# %%
# Suppose df1, df2, and df3 are your three DataFrames
# Plot 'score' column from each DataFrame on the same figure
plt.figure(figsize=(10, 6))
sns.set_style("darkgrid", {"grid.color": ".6", "grid.linestyle": ":"})
color_styles = sns.color_palette("bright")
combined_df = pd.concat([score_df_sol_per_pop_48['score'], score_df_sol_per_pop_24['score'],score_df_sol_per_pop_12['score'], score_df_sol_per_pop_6['score'], score_df_sol_per_pop_3['score']], axis=1)
combined_df.columns = ['sol_per_pop_48', 'sol_per_pop_24', 'sol_per_pop_12', 'sol_per_pop_6', 'sol_per_pop_3']

# Plot the 'score' columns from all three DataFrames using Seaborn
sns.lineplot(data=combined_df)
#plt.plot(score_df_sol_per_pop_12['score'], label='DataFrame 1')
#plt.plot(score_df_sol_per_pop_6['score'], label='DataFrame 2')
#plt.plot(score_df_sol_per_pop_3['score'], label='DataFrame 3')

# Add labels and legend
plt.xlabel('Iteration Time')
plt.ylabel('MOS')
plt.title('PEAQ Value trends collasped in solution per population')
plt.legend()

# Show the plot
plt.show()
# Out:
# /root/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /root/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # Mutation Rate

# %%
GA_MuR_50 = GAParameterClass(num_generations=100,mutation_percent_genes=50,num_parents_mating=2,sol_per_pop=12,crossover_type="single_point")
GA_MuR_50.run()
score_df_MuR_50, manip_df_sol_MuR_50, full_df_sol_MuR_50 = GA_MuR_50.OutputDateFrame()
GA_MuR_30 = GAParameterClass(num_generations=100,mutation_percent_genes=30,num_parents_mating=2,sol_per_pop=12,crossover_type="single_point")
GA_MuR_30.run()
score_df_MuR_30, manip_df_sol_MuR_30, full_df_sol_MuR_30 = GA_MuR_30.OutputDateFrame()
GA_MuR_10 = GAParameterClass(num_generations=100,mutation_percent_genes=10,num_parents_mating=2,sol_per_pop=12,crossover_type="single_point")
GA_MuR_10.run()
score_df_MuR_10, manip_df_sol_MuR_10, full_df_sol_MuR_10 = GA_MuR_10.OutputDateFrame()
# Out:
# Vocal duration orginal is 75.73730158730159 seconds, now is the 8.0, the audio changing to the MONO
# Drum duration orginal is 75.73730158730159 seconds, now is the 8.0, the audio changing to the MONO
# Bass duration orginal is 75.73730158730159 seconds, now is the 8.0, the audio changing to the MONO
# Other duration orginal is 75.73730158730159 seconds, now is the 8.0,  the audio changing to the MONO
# Mixing File Load Sucessful
# /root/anaconda3/lib/python3.11/site-packages/pygad/pygad.py:1139: UserWarning: The 'delay_after_gen' parameter is deprecated starting from PyGAD 3.3.0. To delay or pause the evolution after each generation, assign a callback function/method to the 'on_generation' parameter to adds some time delay.
#   warnings.warn("The 'delay_after_gen' parameter is deprecated starting from PyGAD 3.3.0. To delay or pause the evolution after each generation, assign a callback function/method to the 'on_generation' parameter to adds some time delay.")
# ...

# %%
GA_MuR_70 = GAParameterClass(num_generations=100,mutation_percent_genes=70,num_parents_mating=2,sol_per_pop=12,crossover_type="single_point")
GA_MuR_70.run()
score_df_MuR_70, manip_df_sol_MuR_70, full_df_sol_MuR_70 = GA_MuR_70.OutputDateFrame()
GA_MuR_90 = GAParameterClass(num_generations=100,mutation_percent_genes=90,num_parents_mating=2,sol_per_pop=12,crossover_type="single_point")
GA_MuR_90.run()
score_df_MuR_90, manip_df_sol_MuR_90, full_df_sol_MuR_90 = GA_MuR_90.OutputDateFrame()
# Out:
# Vocal duration orginal is 75.73730158730159 seconds, now is the 8.0, the audio changing to the MONO
# Drum duration orginal is 75.73730158730159 seconds, now is the 8.0, the audio changing to the MONO
# Bass duration orginal is 75.73730158730159 seconds, now is the 8.0, the audio changing to the MONO
# Other duration orginal is 75.73730158730159 seconds, now is the 8.0,  the audio changing to the MONO
# Mixing File Load Sucessful
# /root/anaconda3/lib/python3.11/site-packages/pygad/pygad.py:1139: UserWarning: The 'delay_after_gen' parameter is deprecated starting from PyGAD 3.3.0. To delay or pause the evolution after each generation, assign a callback function/method to the 'on_generation' parameter to adds some time delay.
#   warnings.warn("The 'delay_after_gen' parameter is deprecated starting from PyGAD 3.3.0. To delay or pause the evolution after each generation, assign a callback function/method to the 'on_generation' parameter to adds some time delay.")
# ...

# %%
##Interigrity the data
if score_df_MuR_90["score"][0]>0:
    score_df_MuR_90["score"] = -score_df_MuR_90["score"]
if score_df_MuR_70["score"][0]>0:
    score_df_MuR_70["score"] = -score_df_MuR_70["score"]
if score_df_MuR_50["score"][0]>0:
    score_df_MuR_50["score"] = -score_df_MuR_50["score"]
if score_df_MuR_30["score"][0]>0:
    score_df_MuR_30["score"] = -score_df_MuR_30["score"]
if score_df_MuR_10["score"][0]>0:
    score_df_MuR_10["score"] = -score_df_MuR_10["score"]

# %%
# Suppose df1, df2, and df3 are your three DataFrames
# Plot 'score' column from each DataFrame on the same figure
plt.figure(figsize=(10, 6))
sns.set_style("darkgrid", {"grid.color": ".6", "grid.linestyle": ":"})
color_styles = sns.color_palette("bright")
combined_df = pd.concat([score_df_MuR_90['score'],score_df_MuR_70['score'],score_df_MuR_50['score'], score_df_MuR_30['score'], score_df_MuR_10['score']], axis=1)
combined_df.columns = ['Mutation 90%','Mutation 70%','Mutation 50%', 'Mutation 30%', 'Mutation 10%']

# Plot the 'score' columns from all three DataFrames using Seaborn
sns.lineplot(data=combined_df)
#plt.plot(score_df_sol_per_pop_12['score'], label='DataFrame 1')
#plt.plot(score_df_sol_per_pop_6['score'], label='DataFrame 2')
#plt.plot(score_df_sol_per_pop_3['score'], label='DataFrame 3')

# Add labels and legend
plt.xlabel('Iteration Time')
plt.ylabel('MOS')
plt.title('PEAQ Value trends collasped in mutation rate')
plt.legend()

# Show the plot
plt.show()
# Out:
# /root/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /root/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # Parents number

# %%
GA_Parents_num_6 = GAParameterClass(num_generations=100,mutation_percent_genes=50,num_parents_mating=6,sol_per_pop=12,crossover_type="single_point")
GA_Parents_num_6.run()
GA_Parents_num_4 = GAParameterClass(num_generations=100,mutation_percent_genes=50,num_parents_mating=4,sol_per_pop=12,crossover_type="single_point")
GA_Parents_num_4.run()
GA_Parents_num_3 = GAParameterClass(num_generations=100,mutation_percent_genes=50,num_parents_mating=4,sol_per_pop=12,crossover_type="single_point")
GA_Parents_num_3.run()
GA_Parents_num_2 = GA_MuR_50
# Out:
# Vocal duration orginal is 75.73730158730159 seconds, now is the 8.0, the audio changing to the MONO
# Drum duration orginal is 75.73730158730159 seconds, now is the 8.0, the audio changing to the MONO
# Bass duration orginal is 75.73730158730159 seconds, now is the 8.0, the audio changing to the MONO
# Other duration orginal is 75.73730158730159 seconds, now is the 8.0,  the audio changing to the MONO
# Mixing File Load Sucessful
# /root/anaconda3/lib/python3.11/site-packages/pygad/pygad.py:1139: UserWarning: The 'delay_after_gen' parameter is deprecated starting from PyGAD 3.3.0. To delay or pause the evolution after each generation, assign a callback function/method to the 'on_generation' parameter to adds some time delay.
#   warnings.warn("The 'delay_after_gen' parameter is deprecated starting from PyGAD 3.3.0. To delay or pause the evolution after each generation, assign a callback function/method to the 'on_generation' parameter to adds some time delay.")
# ...

# %%
score_df_Parents_num_6, manip_df_Parents_num_6, full_df_Parents_num_6 = GA_Parents_num_6.OutputDateFrame()
score_df_Parents_num_4, manip_df_Parents_num_4, full_df_Parents_num_4 = GA_Parents_num_4.OutputDateFrame()
score_df_Parents_num_3, manip_df_Parents_num_3, full_df_Parents_num_3 = GA_Parents_num_3.OutputDateFrame()
score_df_Parents_num_2, manip_df_Parents_num_2, full_df_Parents_num_2 = GA_Parents_num_2.OutputDateFrame()

# %%
##Interigrity the data
if score_df_Parents_num_6["score"][0]>0:
    score_df_Parents_num_6["score"] = -score_df_Parents_num_6["score"]
if score_df_Parents_num_4["score"][0]>0:
    score_df_Parents_num_4["score"] = -score_df_Parents_num_4["score"]
if score_df_Parents_num_3["score"][0]>0:
    score_df_Parents_num_3["score"] = -score_df_Parents_num_3["score"]
if score_df_Parents_num_2["score"][0]>0:
    score_df_Parents_num_2["score"] = -score_df_Parents_num_2["score"]

# %%
# Suppose df1, df2, and df3 are your three DataFrames
# Plot 'score' column from each DataFrame on the same figure
plt.figure(figsize=(10, 6))
sns.set_style("darkgrid", {"grid.color": ".6", "grid.linestyle": ":"})
color_styles = sns.color_palette("bright")
combined_df = pd.concat([score_df_Parents_num_6['score'],score_df_Parents_num_4['score'],score_df_Parents_num_3['score'], score_df_Parents_num_2['score']], axis=1)
combined_df.columns = ['Parents_num_6','Parents_num_4','Parents_num_3', 'Parents_num_2']

# Plot the 'score' columns from all three DataFrames using Seaborn
sns.lineplot(data=combined_df)
#plt.plot(score_df_sol_per_pop_12['score'], label='DataFrame 1')
#plt.plot(score_df_sol_per_pop_6['score'], label='DataFrame 2')
#plt.plot(score_df_sol_per_pop_3['score'], label='DataFrame 3')

# Add labels and legend
plt.xlabel('Iteration Time')
plt.ylabel('MOS')
plt.title('PEAQ Value trends collasped in Parent Number')
plt.legend()

# Show the plot
plt.show()
# Out:
# /root/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /root/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
GA_two_points = GAParameterClass(num_generations=100,mutation_percent_genes=50,num_parents_mating=2,sol_per_pop=12,crossover_type="two_points")
GA_two_points.run()
GA_uniform = GAParameterClass(num_generations=100,mutation_percent_genes=50,num_parents_mating=2,sol_per_pop=12,crossover_type="uniform")
GA_uniform.run()
GA_scattered = GAParameterClass(num_generations=100,mutation_percent_genes=50,num_parents_mating=2,sol_per_pop=12,crossover_type="scattered")
GA_scattered.run()
GA_single_point = GA_MuR_50
score_df_two_points, manip_df_two_points, full_df_two_points = GA_two_points.OutputDateFrame()
score_df_uniform, manip_df_uniform, full_df_uniform = GA_uniform.OutputDateFrame()
score_df_scattered, manip_df_scattered, full_df_scattered = GA_scattered.OutputDateFrame()
score_df_single_point, manip_df_single_point, full_df_single_point = GA_single_point.OutputDateFrame()
# Out:
# Vocal duration orginal is 75.73730158730159 seconds, now is the 8.0, the audio changing to the MONO
# Drum duration orginal is 75.73730158730159 seconds, now is the 8.0, the audio changing to the MONO
# Bass duration orginal is 75.73730158730159 seconds, now is the 8.0, the audio changing to the MONO
# Other duration orginal is 75.73730158730159 seconds, now is the 8.0,  the audio changing to the MONO
# Mixing File Load Sucessful
# /root/anaconda3/lib/python3.11/site-packages/pygad/pygad.py:1139: UserWarning: The 'delay_after_gen' parameter is deprecated starting from PyGAD 3.3.0. To delay or pause the evolution after each generation, assign a callback function/method to the 'on_generation' parameter to adds some time delay.
#   warnings.warn("The 'delay_after_gen' parameter is deprecated starting from PyGAD 3.3.0. To delay or pause the evolution after each generation, assign a callback function/method to the 'on_generation' parameter to adds some time delay.")
# ...

# %%
if score_df_single_point["score"][0]>0:
    score_df_single_point["score"] = -score_df_single_point["score"]
if score_df_two_points["score"][0]>0:
    score_df_two_points["score"] = -score_df_two_points["score"]
if score_df_uniform["score"][0]>0:
    score_df_uniform["score"] = -score_df_uniform["score"]
if score_df_scattered["score"][0]>0:
    score_df_scattered["score"] = -score_df_scattered["score"]

# %%
# Suppose df1, df2, and df3 are your three DataFrames
# Plot 'score' column from each DataFrame on the same figure
plt.figure(figsize=(10, 6))
sns.set_style("darkgrid", {"grid.color": ".6", "grid.linestyle": ":"})
color_styles = sns.color_palette("bright")
combined_df = pd.concat([score_df_single_point['score'],score_df_two_points['score'],score_df_uniform['score'], score_df_scattered['score']], axis=1)
combined_df.columns = ['single_point','two_points','uniform', 'scattered']

# Plot the 'score' columns from all three DataFrames using Seaborn
sns.lineplot(data=combined_df)
#plt.plot(score_df_sol_per_pop_12['score'], label='DataFrame 1')
#plt.plot(score_df_sol_per_pop_6['score'], label='DataFrame 2')
#plt.plot(score_df_sol_per_pop_3['score'], label='DataFrame 3')

# Add labels and legend
plt.xlabel('Iteration Time')
plt.ylabel('MOS')
plt.title('PEAQ Value trends collasped in Crossover Type')
plt.legend()

# Show the plot
plt.show()
# Out:
# /root/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /root/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
